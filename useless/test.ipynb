# %%
from PIL import Image,ImageOps
from nst_utils import *
content_image = Image.open('content_images/amber.jpg')
print(type(content_image))
imshow(content_image)
# content_image1 = ImageOps.fit(content_image, (1800, 1800), Image.ANTIALIAS)
out = content_image.resize((1000, 800), Image.ANTIALIAS)
imshow(out)
out.save('reshape_images/1.jpg')
print(out)
print(type(imageio.imread('content_images/amber.jpg')))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# <PIL.Image.Image image mode=RGB size=1000x800 at 0x1BB92926D08>
# <class 'imageio.core.util.Array'>

# %%
reshape_image = imageio.imread('reshape_images/1.jpg')
print(reshape_image.shape)
# Out:
# (800, 1000, 3)

# %%
import tensorflow as tf
matrix1 = tf.constant([[4., 3.]])

# 创建另外一个常量 op, 产生一个 2x1 矩阵.
matrix2 = tf.constant([[2.],[2.]])

# 创建一个矩阵乘法 matmul op , 把 'matrix1' 和 'matrix2' 作为输入.
# 返回值 'product' 代表矩阵乘法的结果.

product = tf.matmul(matrix1, matrix2)
with tf.Session():
    matrix1 = tf.constant([[4., 4.]])
    a = sess.run(product)
    print(a)
    matrix1 = tf.constant([[3., 3.]])
    b = product
    print(b.eval())
# Out:
# [[14.]]
# [[14.]]
